# %%
import pandas as pd
import os

# %%
datasets_path = "../datasets"

movie_filename = "top_movies.csv"
tv_filename = "top_tv.csv"

# %%
movies_df = pd.read_csv(os.path.join(datasets_path, movie_filename))
print(movies_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110915 entries, 0 to 110914
# Data columns (total 25 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Unnamed: 0            110915 non-null  int64
#  1   id                    110915 non-null  int64
#  2   title                 110915 non-null  object
#  3   vote_average          110915 non-null  float64
#  4   vote_count            110915 non-null  int64
#  5   status                110915 non-null  object
#  6   release_date          110833 non-null  object
#  7   revenue               110915 non-null  int64
#  8   runtime               110915 non-null  int64
#  9   adult                 110915 non-null  bool
#  10  backdrop_path         90368 non-null   object
#  11  budget                110915 non-null  int64
#  12  homepage              20914 non-null   object
#  13  imdb_id               109599 non-null  object
#  14  original_language     110915 non-null  object
#  15  original_title        110915 non-null  object
#  16  overview              108589 non-null  object
#  17  popularity            110915 non-null  float64
#  18  poster_path           108724 non-null  object
#  19  tagline               43333 non-null   object
#  20  genres                108344 non-null  object
#  21  production_companies  92308 non-null   object
#  22  production_countries  103205 non-null  object
#  23  spoken_languages      106550 non-null  object
#  24  keywords              72865 non-null   object
# dtypes: bool(1), float64(2), int64(6), object(16)
# memory usage: 20.4+ MB
# None
