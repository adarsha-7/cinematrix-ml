# %%
import pandas as pd
import os

# %%
movies = pd.read_csv(os.path.join("../datasets", "top_movies.csv"))
# Out:
# C:\Users\adars\AppData\Local\Temp\ipykernel_13112\2893035531.py:1: DtypeWarning: Columns (24,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   movies = pd.read_csv(os.path.join("../datasets", "top_movies.csv"))

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110913 entries, 0 to 110912
# Data columns (total 26 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    110913 non-null  int64
#  1   title                 110913 non-null  object
#  2   vote_average          110913 non-null  float64
#  3   vote_count            110913 non-null  int64
#  4   status                110913 non-null  object
#  5   release_date          110831 non-null  object
#  6   revenue               110913 non-null  int64
#  7   runtime               110913 non-null  int64
#  8   adult                 110913 non-null  bool
#  9   backdrop_path         90366 non-null   object
#  10  budget                110913 non-null  int64
#  11  homepage              20914 non-null   object
#  12  imdb_id               109597 non-null  object
#  13  original_language     110913 non-null  object
# ...

# %%
top_movies = movies[movies.vote_count > 20]
print(len(movies))
print(len(top_movies))
# Out:
# 110913
# 48902

# %%
top_movies.to_csv(os.path.join("../datasets", "top_movies.csv"), index=False)
