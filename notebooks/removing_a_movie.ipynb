# %%
import pandas as pd
import os

# %%
movies = pd.read_csv(os.path.join("../datasets", "top_movies.csv"))

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26174 entries, 0 to 26173
# Data columns (total 26 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    26174 non-null  int64
#  1   title                 26174 non-null  object
#  2   vote_average          26174 non-null  float64
#  3   vote_count            26174 non-null  int64
#  4   status                26174 non-null  object
#  5   release_date          26172 non-null  object
#  6   revenue               26174 non-null  int64
#  7   runtime               26174 non-null  int64
#  8   adult                 26174 non-null  bool
#  9   backdrop_path         25911 non-null  object
#  10  budget                26174 non-null  int64
#  11  homepage              7661 non-null   object
#  12  imdb_id               26127 non-null  object
#  13  original_language     26174 non-null  object
#  14  original_title        26174 non-null  object
#  15  overview              26086 non-null  object
#  16  popularity            26174 non-null  float64
#  17  poster_path           26157 non-null  object
#  18  tagline               17116 non-null  object
#  19  genres                26151 non-null  object
#  20  production_companies  25403 non-null  object
#  21  production_countries  25942 non-null  object
#  22  spoken_languages      26108 non-null  object
#  23  keywords              22603 non-null  object
#  24  cast                  23889 non-null  object
#  25  director              23861 non-null  object
# dtypes: bool(1), float64(2), int64(5), object(18)
# memory usage: 5.0+ MB

# %%
movies.loc[23889]
# Out:
# id                                                                 214714
# title                                                               Don't
# vote_average                                                          7.0
# vote_count                                                             64
# status                                                           Released
# release_date                                                   2007-04-05
# revenue                                                                 0
# runtime                                                                 2
# adult                                                               False
# backdrop_path                            /tjRPDvW98OA4lip1kdGJU6i8pzg.jpg
# budget                                                                  0
# homepage                                                              NaN
# imdb_id                                                        tt10432472
# original_language                                                      en
# original_title                                                      Don't
# overview                In 2007, Wright directed a fake trailer insert...
# popularity                                                          6.671
# poster_path                              /vnIuXqa2Mv3DZQCNjPs4Xo30q18.jpg
# tagline                 If you are thinking of seeing this film alone....
# genres                                                     Comedy, Horror
# production_companies    Dimension Films, Big Talk Productions, Eyetron...
# production_countries                                       United Kingdom
# spoken_languages                                                  English
# keywords                                                     gore, parody
# cast                                                                  NaN
# director                                                              NaN
# Name: 23889, dtype: object

# %%
print(len(movies))
movies = movies[movies.id != 214714]
print(len(movies))
# Out:
# 26174
# 26173

# %%
movies.to_csv(os.path.join("../datasets", "top_movies.csv"), index=False)
