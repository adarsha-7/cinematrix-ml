# %%
import pandas as pd
import os

# %%
movies = pd.read_csv(os.path.join("../datasets", "top_tv.csv"))

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5215 entries, 0 to 5214
# Data columns (total 30 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    5215 non-null   int64
#  1   name                  5215 non-null   object
#  2   number_of_seasons     5215 non-null   int64
#  3   number_of_episodes    5215 non-null   int64
#  4   original_language     5215 non-null   object
#  5   vote_count            5215 non-null   int64
#  6   vote_average          5215 non-null   float64
#  7   overview              5099 non-null   object
#  8   adult                 5215 non-null   bool
#  9   backdrop_path         5155 non-null   object
#  10  first_air_date        5205 non-null   object
#  11  last_air_date         5208 non-null   object
#  12  homepage              4173 non-null   object
#  13  in_production         5215 non-null   bool
#  14  original_name         5215 non-null   object
#  15  popularity            5215 non-null   float64
#  16  poster_path           5210 non-null   object
#  17  type                  5215 non-null   object
#  18  status                5215 non-null   object
#  19  tagline               1718 non-null   object
#  20  genres                5176 non-null   object
#  21  created_by            3856 non-null   object
#  22  languages             5190 non-null   object
#  23  networks              5149 non-null   object
#  24  origin_country        5179 non-null   object
#  25  spoken_languages      5187 non-null   object
#  26  production_companies  4542 non-null   object
#  27  production_countries  4431 non-null   object
#  28  episode_run_time      5215 non-null   int64
#  29  cast                  1114 non-null   object
# dtypes: bool(2), float64(2), int64(5), object(21)
# memory usage: 1.1+ MB

# %%
movies.loc[1114]
# Out:
# id                                                                 123566
# name                                                         Metal Family
# number_of_seasons                                                       2
# number_of_episodes                                                     15
# original_language                                                      ru
# vote_count                                                            363
# vote_average                                                          8.6
# overview                Metal Family follows the daily lives of Glam a...
# adult                                                               False
# backdrop_path                            /1ejS56lC8db62IKVj1pTQlfAEQy.jpg
# first_air_date                                                 2018-09-13
# last_air_date                                                  2023-07-29
# homepage                https://www.youtube.com/redirect?event=channel...
# in_production                                                        True
# original_name                                                Metal Family
# popularity                                                         34.869
# poster_path                              /2ts0hvhyai9ozurgNFd9TH0ZrIr.jpg
# type                                                           Miniseries
# status                                                   Returning Series
# tagline                                                               NaN
# genres                       Action & Adventure, Animation, Drama, Family
# created_by                                                 Alina Kovaleva
# languages                                                          en, ru
# networks                                                          YouTube
# origin_country                                                         RU
# spoken_languages                                         English, Pусский
# production_companies                                                  NaN
# production_countries                                               Russia
# episode_run_time                                                        8
# cast                                                                  NaN
# Name: 1114, dtype: object

# %%
print(len(movies))
movies = movies[movies.id != 123566]
print(len(movies))
# Out:
# 5215
# 5214

# %%
movies.to_csv(os.path.join("../datasets", "top_tv.csv"), index=False)
