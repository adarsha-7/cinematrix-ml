# %%
import pandas as pd
import os

# %%
movies = pd.read_csv(os.path.join("../datasets", "top_tv.csv"))

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5214 entries, 0 to 5213
# Data columns (total 30 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    5214 non-null   int64
#  1   name                  5214 non-null   object
#  2   number_of_seasons     5214 non-null   int64
#  3   number_of_episodes    5214 non-null   int64
#  4   original_language     5214 non-null   object
#  5   vote_count            5214 non-null   int64
#  6   vote_average          5214 non-null   float64
#  7   overview              5098 non-null   object
#  8   adult                 5214 non-null   bool
#  9   backdrop_path         5154 non-null   object
#  10  first_air_date        5204 non-null   object
#  11  last_air_date         5207 non-null   object
#  12  homepage              4172 non-null   object
#  13  in_production         5214 non-null   bool
#  14  original_name         5214 non-null   object
# ...

# %%
movies.loc[1320]
# Out:
# id                                                                   6516
# name                                                  The Bugs Bunny Show
# number_of_seasons                                                       3
# number_of_episodes                                                     78
# original_language                                                      en
# vote_count                                                            293
# vote_average                                                        8.024
# overview                The Bugs Bunny Show is an Animated television ...
# adult                                                               False
# backdrop_path                            /fMdSu4ODWwWaSFVwNnIP1iimSP6.jpg
# first_air_date                                                 1960-10-11
# last_air_date                                                  1972-03-04
# homepage                                                              NaN
# ...

# %%
print(len(movies))
movies = movies[movies.id != 6516]
print(len(movies))
# Out:
# 5214
# 5213

# %%
movies.to_csv(os.path.join("../datasets", "top_tv.csv"), index=False)
