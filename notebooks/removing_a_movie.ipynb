# %%
import pandas as pd
import os

# %%
movies = pd.read_csv(os.path.join("../datasets", "top_movies.csv"))

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26181 entries, 0 to 26180
# Data columns (total 26 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    26181 non-null  int64
#  1   title                 26181 non-null  object
#  2   vote_average          26181 non-null  float64
#  3   vote_count            26181 non-null  int64
#  4   status                26181 non-null  object
#  5   release_date          26179 non-null  object
#  6   revenue               26181 non-null  int64
#  7   runtime               26181 non-null  int64
#  8   adult                 26181 non-null  bool
#  9   backdrop_path         25918 non-null  object
#  10  budget                26181 non-null  int64
#  11  homepage              7665 non-null   object
#  12  imdb_id               26134 non-null  object
#  13  original_language     26181 non-null  object
#  14  original_title        26181 non-null  object
#  15  overview              26093 non-null  object
#  16  popularity            26181 non-null  float64
#  17  poster_path           26164 non-null  object
#  18  tagline               17117 non-null  object
#  19  genres                26158 non-null  object
#  20  production_companies  25409 non-null  object
#  21  production_countries  25949 non-null  object
#  22  spoken_languages      26115 non-null  object
#  23  keywords              22609 non-null  object
#  24  cast                  17820 non-null  object
#  25  director              17810 non-null  object
# dtypes: bool(1), float64(2), int64(5), object(18)
# memory usage: 5.0+ MB

# %%
movies.loc[17820]
# Out:
# id                                                                 434822
# title                                                        Good Morning
# vote_average                                                        7.675
# vote_count                                                            103
# status                                                           Released
# release_date                                                   2007-12-10
# revenue                                                                 0
# runtime                                                                 1
# adult                                                               False
# backdrop_path                            /gO7dSl8U1WPAiJrBDAUmiMbLjtF.jpg
# budget                                                                  0
# homepage                https://web.archive.org/web/20080822011051/htt...
# imdb_id                                                         tt4110118
# original_language                                                      ja
# original_title                                                       オハヨウ
# overview                      Follows a woman as she becomes fully awake.
# popularity                                                          4.546
# poster_path                              /3hUFdj4R0wdkQvOK0e7ECw9Osa8.jpg
# tagline                                                               NaN
# genres                                                   Animation, Drama
# production_companies                                   STUDIO4℃, Madhouse
# production_countries                                                Japan
# spoken_languages                                                 Japanese
# keywords                                                anime, short film
# cast                                                                  NaN
# director                                                              NaN
# Name: 17820, dtype: object

# %%
print(len(movies))
movies = movies[movies.id != 434822]
print(len(movies))
# Out:
# 26181
# 26180

# %%
movies.to_csv(os.path.join("../datasets", "top_movies.csv"), index=False)
