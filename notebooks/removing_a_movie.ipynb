# %%
import pandas as pd
import os

# %%
movies = pd.read_csv(os.path.join("../datasets", "top_movies.csv"))

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26167 entries, 0 to 26166
# Data columns (total 26 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    26167 non-null  int64
#  1   title                 26167 non-null  object
#  2   vote_average          26167 non-null  float64
#  3   vote_count            26167 non-null  int64
#  4   status                26167 non-null  object
#  5   release_date          26165 non-null  object
#  6   revenue               26167 non-null  int64
#  7   runtime               26167 non-null  int64
#  8   adult                 26167 non-null  bool
#  9   backdrop_path         25905 non-null  object
#  10  budget                26167 non-null  int64
#  11  homepage              7660 non-null   object
#  12  imdb_id               26120 non-null  object
#  13  original_language     26167 non-null  object
#  14  original_title        26167 non-null  object
#  15  overview              26079 non-null  object
#  16  popularity            26167 non-null  float64
#  17  poster_path           26150 non-null  object
#  18  tagline               17111 non-null  object
#  19  genres                26144 non-null  object
#  20  production_companies  25397 non-null  object
#  21  production_countries  25935 non-null  object
#  22  spoken_languages      26101 non-null  object
#  23  keywords              22598 non-null  object
#  24  cast                  25556 non-null  object
#  25  director              25524 non-null  object
# dtypes: bool(1), float64(2), int64(5), object(18)
# memory usage: 5.0+ MB

# %%
movies.loc[25556]
# Out:
# id                                                                 190250
# title                                                                 ABE
# vote_average                                                        5.947
# vote_count                                                             57
# status                                                           Released
# release_date                                                   2013-04-16
# revenue                                                                 0
# runtime                                                                 8
# adult                                                               False
# backdrop_path                            /h2AsPI1oZZ7MBORIZHIe9O2g2o0.jpg
# budget                                                                  0
# homepage                                         http://www.abemovie.com/
# imdb_id                                                         tt2883236
# original_language                                                      en
# original_title                                                        ABE
# overview                A short film about a robot programmed for love...
# popularity                                                          2.341
# poster_path                              /eX5RExVtLwhjFo1Ze7ioxw2oeKl.jpg
# tagline                                                               NaN
# genres                                  Science Fiction, Thriller, Horror
# production_companies                                                  NaN
# production_countries                                       United Kingdom
# spoken_languages                                                  English
# keywords                                                       short film
# cast                                                                  NaN
# director                                                              NaN
# Name: 25556, dtype: object

# %%
print(len(movies))
movies = movies[movies.id != 190250]
print(len(movies))
# Out:
# 26167
# 26166

# %%
movies.to_csv(os.path.join("../datasets", "top_movies.csv"), index=False)
