# %%
import pandas as pd
import os

# %%
movies = pd.read_csv(os.path.join("../datasets", "top_movies.csv"))

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26179 entries, 0 to 26178
# Data columns (total 26 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    26179 non-null  int64
#  1   title                 26179 non-null  object
#  2   vote_average          26179 non-null  float64
#  3   vote_count            26179 non-null  int64
#  4   status                26179 non-null  object
#  5   release_date          26177 non-null  object
#  6   revenue               26179 non-null  int64
#  7   runtime               26179 non-null  int64
#  8   adult                 26179 non-null  bool
#  9   backdrop_path         25916 non-null  object
#  10  budget                26179 non-null  int64
#  11  homepage              7664 non-null   object
#  12  imdb_id               26132 non-null  object
#  13  original_language     26179 non-null  object
#  14  original_title        26179 non-null  object
# ...

# %%
movies.loc[18489]
# Out:
# id                                                                 456504
# title                             Alien: Covenant - Prologue: Last Supper
# vote_average                                                         6.01
# vote_count                                                             97
# status                                                           Released
# release_date                                                   2017-02-22
# revenue                                                                 0
# runtime                                                                 5
# adult                                                               False
# backdrop_path                             /9DNyvoopIb6k616UZr4IB2SPGo.jpg
# budget                                                                  0
# homepage                      https://www.youtube.com/watch?v=EkXgRlRao5I
# imdb_id                                                         tt6571148
# ...

# %%
print(len(movies))
movies = movies[movies.id != 456504]
print(len(movies))
# Out:
# 26179
# 26178

# %%
movies.to_csv(os.path.join("../datasets", "top_movies.csv"), index=False)
